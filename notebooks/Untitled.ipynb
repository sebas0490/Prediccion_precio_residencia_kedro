# %%
import pandas as pd

# %%
path = r'C:\Users\jevo1\Documents\Python Scripts\Prediccion_precio_residencia_kedro\data\02_intermediate'
train_test = r'df_train_test.parquet'
validation = r'df_validation.parquet'

# %%
pd.read_parquet(path + '/' +train_test)
# Out:
#        grade  bathrooms  sqft_living15  zipcode  floors  waterfront  \
# 51845    8.0       2.50         2270.0  98056.0     2.0         0.0
# 16822    8.0       2.00         2540.0  98144.0     2.0         0.0
# 11844   10.0       4.50         2810.0  98027.0     1.5         0.0
# 26890   10.0       3.25         3590.0  98006.0     2.0         0.0
# 44019   11.0       3.50         3770.0  98077.0     2.0         0.0
# ...      ...        ...            ...      ...     ...         ...
# 14375    7.0       2.00         1570.0  98038.0     1.0         0.0
# 29775    7.0       2.00         1940.0  98155.0     1.0         0.0
# 5801     7.0       1.75         2140.0  98022.0     1.0         0.0
# 16610    7.0       1.50         1620.0  98034.0     1.0         0.0
# 235      6.0       1.00         1480.0  98117.0     1.0         0.0
#
#        condition  fue_renovada  antiguedad_venta  sqft_lot15  sqft_living  \
# 51845        3.0             0              16.0      5400.0       2600.0
# ...
